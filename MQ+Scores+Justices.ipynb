# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\ravgh\\Desktop\\justices.csv",na_values=["N/A","Unknown"],
encoding='UTF-8')

# %%
df.head()
# Out:
#    term  justice justiceName  post_mn  post_sd  post_med  post_025  post_975
# 0  1965       97     AFortas   -1.403    0.274    -1.398    -1.967    -0.898
# 1  1966       97     AFortas   -1.566    0.234    -1.558    -2.033    -1.122
# 2  1967       97     AFortas   -1.479    0.240    -1.471    -1.975    -1.037
# 3  1968       97     AFortas   -1.292    0.316    -1.279    -1.954    -0.712
# 4  1962       96  AJGoldberg   -1.094    0.227    -1.085    -1.560    -0.673

# %%
df['year'] = pd.to_datetime(df.term, format='%Y')

# %%
plt.figure(figsize=(10,5))
df.set_index('year').groupby('justiceName').post_mn.plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, ncol=3)

# %%
df [df.justiceName.isin(["CThomas", "AScalia", "JGRoberts", "AMKennedy", "RBGinsburg", 
   "SSotomayor", "SGBreyer", "SAAlito", "EKagan"])].set_index('year').groupby('justiceName').post_mn.plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, ncol=2)
